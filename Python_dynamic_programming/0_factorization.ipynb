# %%
#factor a given number
number = raw_input("Which integer do you want to factorize? ")
number = int(number)

#find factors
for i in range (1,number+1):
    if number%i == 0:print i
# Out:
# Which integer do you want to factorize? 9000000
# 1
# 2
# 3
# 4
# 5
# 6
# 8
# 9
# 10
# 12
# 15
# 16
# 18
# 20
# 24
# 25
# 30
# 32
# 36
# 40
# 45
# 48
# 50
# 60
# 64
# 72
# 75
# 80
# 90
# 96
# 100
# 120
# 125
# 144
# 150
# 160
# 180
# 192
# 200
# 225
# 240
# 250
# 288
# 300
# 320
# 360
# 375
# 400
# 450
# 480
# 500
# 576
# 600
# 625
# 720
# 750
# 800
# 900
# 960
# 1000
# 1125
# 1200
# 1250
# 1440
# 1500
# 1600
# 1800
# 1875
# 2000
# 2250
# 2400
# 2500
# 2880
# 3000
# 3125
# 3600
# 3750
# 4000
# 4500
# 4800
# 5000
# 5625
# 6000
# 6250
# 7200
# 7500
# 8000
# 9000
# 9375
# 10000
# 11250
# 12000
# 12500
# 14400
# 15000
# 15625
# 18000
# 18750
# 20000
# 22500
# 24000
# 25000
# 28125
# 30000
# 31250
# 36000
# 37500
# 40000
# 45000
# 46875
# 50000
# 56250
# 60000
# 62500
# 72000
# 75000
# 90000
# 93750
# 100000
# 112500
# 120000
# 125000
# 140625
# 150000
# 180000
# 187500
# 200000
# 225000
# 250000
# 281250
# 300000
# 360000
# 375000
# 450000
# 500000
# 562500
# 600000
# 750000
# 900000
# ...

# %%
900000
